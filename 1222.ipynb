# %%
import my_utils as mu
import pandas as pd

# %%
df = mu.get_rawdata('GOLD')
# Out:
# get summonerId....
# 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# get puuId.....
# 100%|██████████| 12/12 [00:07<00:00,  1.57it/s]
# get match_id....
# 100%|██████████| 12/12 [00:08<00:00,  1.48it/s]
# get matches & timeline....
# 100%|██████████| 36/36 [00:56<00:00,  1.57s/it]

# %%
def lane_processing(tower_lane,tower_team,lane,team):
    if(tower_lane[0] == lane[0]) and (tower_team == team):
       return 1
    else:
       return 0

# %%
def assi_calc(y):
    try:
        return ','.join(list(map(lambda x:str(x),y['assistingParticipantIds'])))
    except:
        return ''

# %%
df_creates = []
for i in range(len(df)):
    for j in range(10):
        try:
            riotGameName = df.iloc[0].matches['info']['partcipants'][0]['riotGamename']
        except:
            continue
        
        df_creates = []
for i in range(len(df)):
    
    try:
        match = df.iloc[i].matches['info']['participants']
        for j in range(len(match)):
            match_id = df.iloc[i].match_id
            game_duration = df.iloc[i].matches['info']['gameDuration']
            game_version = df.iloc[i].matches['info']['gameVersion']
            try:
                riotIdGameName = match[j]['riotIdGameName']
            except:
                riotIdGameName = ''
            try:
                riotIdTagline = match[j]['riotIdTagline']
            except:
                riotIdTagline = ''
            summoner_level = match[j]['summonerLevel']
            participants_id = match[j]['participantId']
            champion_name = match[j]['championName']
            champ_experience = match[j]['champExperience']
            team_position = match[j]['teamPosition']
            team_id = match[j]['teamId']
            win = match[j]['win']
            kills = match[j]['kills']
            deaths = match[j]['deaths']
            assists = match[j]['assists']
            total_damage_dealt = match[j]['totalDamageDealtToChampions']
            total_damage_taken = match[j]['totalDamageTaken'],

            df_list = list(map(lambda x: x['events'],df.iloc[i].timelines['info']['frames']))
            event_list = [element for array in df_list for element in array]
            tower_log = list(filter(lambda x:x['type']== 'BUILDING_KILL' ,event_list))

            try:
                ft_tower_lane = tower_log[0]['laneType']
                ft_tower_team = tower_log[0]['teamId']
            except:
                ft_tower_lane ='n'
                ft_tower_team ='n'
            ft = lane_processing(ft_tower_lane,ft_tower_team,team_position,team_id)    

            tower_tmp = list(map(lambda x:(x['laneType'],x['teamId'],x['timestamp']),tower_log))

            try:
                laneTower = list(filter(lambda x:(x[0][0]==team_position[0])&(x[1]==team_id),tower_tmp))[0]
                lane_flag = 1
                laneTowerTime = laneTower[-1]
            except:
                lane_flag = 0
                laneTowerTime = 0
                
                
            blue_ban = list(map(lambda x:str(x['championId']) ,df.iloc[i].matches['info']['teams'][0]['bans']))    
            red_ban = list(map(lambda x:str(x['championId']) ,df.iloc[i].matches['info']['teams'][0]['bans']))
            ban_list ='|'.join(list(set(blue_ban + red_ban)))
            
            
            kill_log = list(map(lambda x:list(filter(lambda z:z['type']=='CHAMPION_KILL',x['events'])),df.iloc[i].timelines['info']['frames']))
            kill_log = [element for array in kill_log for element in array]
            k = '|'.join(list(map(lambda x : str(x['killerId']),kill_log)))
            v = '|'.join(list(map(lambda x : str(x['victimId']),kill_log)))
            a = '|'.join(list(map(lambda x : assi_calc(x),kill_log)))

            try:
                g15 = df.iloc[i].timelines['info']['frames'][15]['participantFrames'][(str(j+1))]['totalGold']
            except:
                g15 = 0
            
            
            df_creates.append([match_id,game_duration,game_version,riotIdGameName,riotIdTagline,summoner_level,participants_id,
                              champion_name,champ_experience,team_position,team_id,win,kills,deaths,assists,
                               total_damage_dealt,total_damage_taken,ft,lane_flag,laneTowerTime,ban_list,k,v,a,g15])
    
    except:
        continue
        
        
columns =['matchId', 'gameDuration', 'gameVersion', 'riotIdGameName','riotIdTagline', 
           'summonerLevel', 'participantId', 'championName', 'champExperience', 
           'teamPosition', 'teamId', 'win', 'kills', 'deaths', 'assists', 'totalDamageDealtToChampions', 'totalDamageTaken',
         'firstDT','laneTower','LaneTowerTime','bans','killerId','victimId','assistId','G15']

df2 = pd.DataFrame(df_creates , columns = columns)

# %%
tower_tmp
# Out:
# [('MID_LANE', 100, 848793),
#  ('BOT_LANE', 100, 1018975),
#  ('TOP_LANE', 100, 1046079),
#  ('MID_LANE', 100, 1212596),
#  ('MID_LANE', 100, 1278216),
#  ('MID_LANE', 100, 1289978),
#  ('BOT_LANE', 100, 1494845),
#  ('TOP_LANE', 100, 1565238),
#  ('TOP_LANE', 100, 1597207),
#  ('MID_LANE', 100, 1645566),
#  ('MID_LANE', 100, 1734523),
#  ('MID_LANE', 100, 1739263),
#  ('MID_LANE', 200, 1742222)]

# %%
df
# Out:
#          match_id                                            matches  \
# 0   KR_6740531033  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   KR_6740475392  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   KR_6740389922  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   KR_6683360452  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   KR_6656935677  {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   KR_6656861249  {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   KR_6831726288  {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   KR_6739578351  {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   KR_6739547971  {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   KR_6858985149  {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  KR_6858914194  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  KR_6856196766  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  KR_6859085076  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  KR_6859035354  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  KR_6858959707  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  KR_6750862202  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  KR_6750755615  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  KR_6750673616  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  KR_6857977672  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  KR_6853805079  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  KR_6827167948  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  KR_6854012023  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  KR_6853973852  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  KR_6853931597  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  KR_6785212238  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  KR_6768045075  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  KR_6767929551  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  KR_6832071146  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  KR_6832033950  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  KR_6831993760  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  KR_6835089301  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  KR_6799101326  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  KR_6799094003  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  KR_6790405735  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  KR_6790374836  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  KR_6783884417  {'metadata': {'dataVersion': '2', 'matchId': '...
#
#                                             timelines
# 0   {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  {'metadata': {'dataVersion': '2', 'matchId': '...

# %%
df2
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6740475392          2491  13.19.534.5972
# 1    KR_6740475392          2491  13.19.534.5972
# 2    KR_6740475392          2491  13.19.534.5972
# 3    KR_6740475392          2491  13.19.534.5972
# 4    KR_6740475392          2491  13.19.534.5972
# ..             ...           ...             ...            ...           ...
# 315  KR_6783884417          1749  13.21.539.4823
# 316  KR_6783884417          1749  13.21.539.4823
# 317  KR_6783884417          1749  13.21.539.4823
# 318  KR_6783884417          1749  13.21.539.4823
# 319  KR_6783884417          1749  13.21.539.4823
#
#      summonerLevel  participantId  championName  champExperience teamPosition  \
# 0              128              1       Evelynn            20922       JUNGLE
# 1               46              2    Blitzcrank            15461      UTILITY
# 2              400              3         Talon            20584       MIDDLE
# 3              169              4       Chogath            21383          TOP
# 4              432              5         Vayne            21404       BOTTOM
# ..             ...            ...           ...              ...          ...
# 315            248              6      Malphite            14929          TOP
# 316            321              7  FiddleSticks            13490       JUNGLE
# 317             88              8         Yasuo            17074       MIDDLE
# 318            155              9        Ezreal            13504       BOTTOM
# 319            140             10           Lux            10525      UTILITY
#
#      ...  totalDamageDealtToChampions  totalDamageTaken  firstDT  laneTower  \
# 0    ...                        47409          (59270,)        0          0
# 1    ...                         9699          (33513,)        0          0
# 2    ...                        46541          (41052,)        0          1
# 3    ...                        27902          (66045,)        0          1
# 4    ...                        62688          (45343,)        0          1
# ..   ...                          ...               ...      ...        ...
# 315  ...                        13838          (18397,)        0          0
# 316  ...                        17826          (32195,)        0          0
# 317  ...                        20757          (22856,)        0          1
# 318  ...                        36263          (18078,)        0          0
# 319  ...                         8349           (8969,)        0          0
#
#      LaneTowerTime                bans  \
# 0                0  101|30|360|127|122
# 1                0  101|30|360|127|122
# 2          1788453  101|30|360|127|122
# 3           857280  101|30|360|127|122
# 4          1257995  101|30|360|127|122
# ..             ...                 ...
# 315              0   39|517|412|111|11
# 316              0   39|517|412|111|11
# 317        1742222   39|517|412|111|11
# 318              0   39|517|412|111|11
# 319              0   39|517|412|111|11
#
#                                               killerId  \
# 0    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 1    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 2    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 3    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 4    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# ..                                                 ...
# 315  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 316  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 317  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 318  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 319  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
#
#                                               victimId  \
# 0    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 1    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 2    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 3    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 4    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# ..                                                 ...
# 315  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 316  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 317  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 318  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 319  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
#
#                                               assistId   G15
# 0    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6210
# 1    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  3657
# 2    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6545
# 3    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  4451
# 4    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  5944
# ..                                                 ...   ...
# 315  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5226
# 316  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5147
# 317  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6569
# 318  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6734
# 319  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  4255
#
# [320 rows x 25 columns]

# %%
df_list = list(map(lambda x: x['events'],df.iloc[i].timelines['info']['frames']))
event_list = [element for array in df_list for element in array]
tower_log = list(filter(lambda x:x['type']== 'BUILDING_KILL' ,event_list))

# %%
tower_log[0]
# Out:
# {'bounty': 0,
#  'buildingType': 'TOWER_BUILDING',
#  'killerId': 8,
#  'laneType': 'MID_LANE',
#  'position': {'x': 5846, 'y': 6396},
#  'teamId': 100,
#  'timestamp': 848793,
#  'towerType': 'OUTER_TURRET',
#  'type': 'BUILDING_KILL'}

# %%
tower_tmp = list(map(lambda x:(x['laneType'],x['teamId'],x['timestamp']),tower_log))

# %%
tower_tmp
# Out:
# [('MID_LANE', 100, 848793),
#  ('BOT_LANE', 100, 1018975),
#  ('TOP_LANE', 100, 1046079),
#  ('MID_LANE', 100, 1212596),
#  ('MID_LANE', 100, 1278216),
#  ('MID_LANE', 100, 1289978),
#  ('BOT_LANE', 100, 1494845),
#  ('TOP_LANE', 100, 1565238),
#  ('TOP_LANE', 100, 1597207),
#  ('MID_LANE', 100, 1645566),
#  ('MID_LANE', 100, 1734523),
#  ('MID_LANE', 100, 1739263),
#  ('MID_LANE', 200, 1742222)]

# %%
laneTower = list(filter(lambda x:(x[0][0]==team_position[0])&(x[1]==team_id),tower_tmp))

# %%
laneTower
# Out:
# []

# %%
team_position = 'BOTTOM'
team_id = 100

# %%
blue_ban = list(map(lambda x:str(x['championId']) ,df.iloc[i].matches['info']['teams'][0]['bans']))    
red_ban = list(map(lambda x:str(x['championId']) ,df.iloc[i].matches['info']['teams'][0]['bans']))
ban_list ='|'.join(list(set(blue_ban + red_ban)))

# %%
kill_log = list(map(lambda x:list(filter(lambda z:z['type']=='CHAMPION_KILL',x['events'])),df.iloc[i].timelines['info']['frames']))

# %%
kill_log
# Out:
# [[],
#  [],
#  [],
#  [{'assistingParticipantIds': [10],
#    'bounty': 400,
#    'killStreakLength': 0,
#    'killerId': 9,
#    'position': {'x': 11967, 'y': 2091},
#    'shutdownBounty': 0,
#    'timestamp': 142857,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 10,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 58,
#      'spellName': 'kaisabasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 58,
#      'spellName': 'kaisabasicattack3',
#      'spellSlot': 66,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 17,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 61,
#      'spellName': 'kaisaeattack3',
#      'spellSlot': 69,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 61,
#      'spellName': 'kaisabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 61,
#      'spellName': 'kaisaeattack2',
#      'spellSlot': 68,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 73,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxlightbinding',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 43,
#      'spellName': 'luxbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 39,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 10,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 28,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxilluminationpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 83,
#      'spellName': 'luxbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 70,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 59,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 355,
#      'spellName': 'ezrealbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 179,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionRanged',
#      'participantId': 0,
#      'physicalDamage': 27,
#      'spellName': 'sru_chaosminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionRanged',
#      'participantId': 0,
#      'physicalDamage': 9,
#      'spellName': 'sru_chaosminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'}],
#    'victimId': 4}],
#  [{'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 8,
#    'position': {'x': 5322, 'y': 6117},
#    'shutdownBounty': 0,
#    'timestamp': 234308,
#    'type': 'CHAMPION_KILL',
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 105,
#      'spellName': 'yasuoq1wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 3}],
#  [{'assistingParticipantIds': [4],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 5,
#    'position': {'x': 13242, 'y': 2253},
#    'shutdownBounty': 0,
#    'timestamp': 240312,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 4,
#      'physicalDamage': 182,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 4,
#      'physicalDamage': 41,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 4,
#      'physicalDamage': 418,
#      'spellName': 'ezrealbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 5,
#      'physicalDamage': 101,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionRanged',
#      'participantId': 0,
#      'physicalDamage': 9,
#      'spellName': 'sru_orderminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': False,
#      'magicDamage': 67,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 78,
#      'spellName': 'yuumip',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 39,
#      'spellName': 'yuumibasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 49,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 99,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 0,
#      'spellName': 'kaisaw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 57,
#      'spellName': '',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 109,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 43,
#      'spellName': 'kaisaq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 118,
#      'spellName': 'kaisabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 118,
#      'spellName': 'kaisabasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 9},
#   {'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 2,
#    'position': {'x': 4730, 'y': 8601},
#    'shutdownBounty': 0,
#    'timestamp': 245047,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 51,
#      'name': 'Yasuo',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'yasuoe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 27,
#      'spellName': 'sru_orderminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 30,
#      'spellName': 'sru_orderminionsiegebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 17,
#      'spellName': 'sru_orderminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 37,
#      'spellName': 'sru_orderminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Turret',
#      'participantId': 0,
#      'physicalDamage': 169,
#      'spellName': 'turretbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'TOWER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 88,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'twoshivpoison',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 8},
#   {'assistingParticipantIds': [8],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 7,
#    'position': {'x': 4837, 'y': 8195},
#    'shutdownBounty': 0,
#    'timestamp': 252695,
#    'type': 'CHAMPION_KILL',
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'burning',
#      'spellSlot': -1,
#      'trueDamage': 20,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 221,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'fiddlesticksw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 60,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'fiddlesticksq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 42,
#      'spellName': 'fiddlesticksbasicattackmelee2',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 58,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'fiddlestickse',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 44,
#      'spellName': 'fiddlesticksbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 51,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'yasuoe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 2}],
#  [{'assistingParticipantIds': [10],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 9,
#    'position': {'x': 11695, 'y': 1371},
#    'shutdownBounty': 0,
#    'timestamp': 327373,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 61,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 79,
#      'spellName': 'yuumip',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 80,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 39,
#      'spellName': 'yuumibasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 17,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 4,
#      'spellName': 'sru_chaosminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 188,
#      'spellName': 'ezrealbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 146,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ezrealw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 52,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 118,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 16,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 43,
#      'spellName': 'luxbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 68,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxlightstrikekugel',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 52,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxilluminationpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 43,
#      'spellName': 'luxbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 5},
#   {'assistingParticipantIds': [2],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 4,
#    'position': {'x': 10166, 'y': 1252},
#    'shutdownBounty': 0,
#    'timestamp': 352661,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 71,
#      'name': 'Ezreal',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'ezreale',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 223,
#      'spellName': 'shacobasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 103,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'twoshivpoison',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 78,
#      'spellName': 'shacobasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 108,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 0,
#      'spellName': 'kaisaw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 26,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 9}],
#  [{'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 6,
#    'position': {'x': 3438, 'y': 13154},
#    'shutdownBounty': 0,
#    'timestamp': 381631,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'Kennen',
#      'participantId': 6,
#      'physicalDamage': 49,
#      'spellName': 'kennenbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kennen',
#      'participantId': 6,
#      'physicalDamage': 49,
#      'spellName': 'kennenbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 30,
#      'name': 'Kennen',
#      'participantId': 6,
#      'physicalDamage': 58,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 206,
#      'name': 'Kennen',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'kennenshurikenhurlmissile1',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 47,
#      'name': 'Kennen',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'kennenlightningrush',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 23,
#      'name': 'Kennen',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'kennenshurikenstorm',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 425,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'seismicshard',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 142,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 171,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'ufslash',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 125,
#      'spellName': 'obduracy',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 86,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'landslide',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 50,
#      'spellName': 'malphitebasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 15,
#      'spellName': 'sru_chaosminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Turret',
#      'participantId': 0,
#      'physicalDamage': 417,
#      'spellName': 'turretbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'TOWER'}],
#    'victimId': 1}],
#  [{'bounty': 274,
#    'killStreakLength': 0,
#    'killerId': 8,
#    'position': {'x': 6081, 'y': 10597},
#    'shutdownBounty': 0,
#    'timestamp': 447008,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'neekoe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 322,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'neekoq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'neekor',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 109,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'yasuoe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 248,
#      'spellName': 'yasuoq1wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 146,
#      'spellName': 'yasuor',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 124,
#      'spellName': 'yasuoq3wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 124,
#      'spellName': 'yasuoq2wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 59,
#      'spellName': 'yasuobasicattack4',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 190,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 121,
#      'spellName': 'yasuobasicattack',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 3},
#   {'assistingParticipantIds': [8],
#    'bounty': 300,
#    'killStreakLength': 1,
#    'killerId': 6,
#    'position': {'x': 4558, 'y': 9725},
#    'shutdownBounty': 0,
#    'timestamp': 464561,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 8,
#      'physicalDamage': 97,
#      'spellName': 'shacobasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 303,
#      'name': 'Shaco',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'twoshivpoison',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 8,
#      'physicalDamage': 89,
#      'spellName': 'shacobasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 66,
#      'name': 'Shaco',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'jackinthebox',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 90,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 137,
#      'spellName': 'yasuoq2wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 137,
#      'spellName': 'yasuoq1wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 275,
#      'spellName': 'yasuoq3wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 131,
#      'spellName': 'yasuobasicattack2',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 58,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'yasuoe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 65,
#      'spellName': 'yasuobasicattack',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 65,
#      'spellName': 'yasuobasicattack3',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 65,
#      'spellName': 'yasuobasicattack4',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 174,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'seismicshard',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 2},
#   {'assistingParticipantIds': [10],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 9,
#    'position': {'x': 10871, 'y': 2369},
#    'shutdownBounty': 0,
#    'timestamp': 469495,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 62,
#      'spellName': '',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 95,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 60,
#      'spellName': 'kaisaeattack4',
#      'spellSlot': 70,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 44,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 62,
#      'spellName': 'kaisaeattack3',
#      'spellSlot': 69,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 62,
#      'spellName': 'kaisaeattack',
#      'spellSlot': 67,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 83,
#      'spellName': 'kaisaq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 62,
#      'spellName': 'kaisaeattack2',
#      'spellSlot': 68,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 28,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 33,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 65,
#      'spellName': 'kaisabasicattack3',
#      'spellSlot': 66,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 65,
#      'spellName': 'kaisabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 65,
#      'spellName': 'kaisabasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 36,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 108,
#      'spellName': 'ezrealbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 90,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 263,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 307,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ezrealr',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 60,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 18,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 135,
#      'spellName': 'luxbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 96,
#      'spellName': 'luxbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 123,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxlightstrikekugel',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 66,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxilluminationpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 4},
#   {'assistingParticipantIds': [10],
#    'bounty': 300,
#    'killStreakLength': 1,
#    'killerId': 9,
#    'position': {'x': 11009, 'y': 1434},
#    'shutdownBounty': 0,
#    'timestamp': 471427,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 18,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 9,
#      'physicalDamage': 37,
#      'spellName': 'yuumibasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 61,
#      'name': 'Yuumi',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 10,
#      'physicalDamage': 39,
#      'spellName': 'yuumibasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 50,
#      'name': 'Yuumi',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 103,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 149,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 157,
#      'spellName': 'ezrealbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 323,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ezrealr',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 45,
#      'spellName': 'luxbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxlightbinding',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 5}],
#  [{'assistingParticipantIds': [7],
#    'bounty': 219,
#    'killStreakLength': 1,
#    'killerId': 8,
#    'position': {'x': 7558, 'y': 8014},
#    'shutdownBounty': 0,
#    'timestamp': 515010,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 158,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'neekoq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 17,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 136,
#      'spellName': 'yasuoq3wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 65,
#      'spellName': 'yasuobasicattack2',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 136,
#      'spellName': 'yasuoq2wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 136,
#      'spellName': 'yasuoq1wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 131,
#      'spellName': 'yasuobasicattack4',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 65,
#      'spellName': 'yasuobasicattack3',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 131,
#      'spellName': 'yasuobasicattack',
#      'spellSlot': 49,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 70,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'fiddlesticksq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 76,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'fiddlestickse',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 61,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'itembloodmoonbootsactive',
#      'spellSlot': 6,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 374,
#      'name': 'FiddleSticks',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'fiddlesticksw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 3},
#   {'assistingParticipantIds': [10],
#    'bounty': 300,
#    'killStreakLength': 2,
#    'killerId': 9,
#    'position': {'x': 10911, 'y': 1751},
#    'shutdownBounty': 0,
#    'timestamp': 522113,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 16,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 22,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 62,
#      'spellName': 'kaisabasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 9,
#      'physicalDamage': 62,
#      'spellName': 'kaisabasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 28,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 33,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 136,
#      'spellName': 'kaisabasicattack3',
#      'spellSlot': 66,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 10,
#      'physicalDamage': 65,
#      'spellName': 'kaisabasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 37,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 89,
#      'spellName': 'luxbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 44,
#      'spellName': 'luxbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 90,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxlightstrikekugel',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 111,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxlightbinding',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 61,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxilluminationpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 108,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 157,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 61,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 249,
#      'spellName': 'ezrealbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 82,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ezrealw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 50,
#      'spellName': 'sru_chaosminionsiegebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 50,
#      'spellName': 'sru_chaosminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 10,
#      'spellName': 'sru_chaosminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'}],
#    'victimId': 4},
#   {'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 2,
#    'position': {'x': 6705, 'y': 6989},
#    'shutdownBounty': 150,
#    'timestamp': 530753,
#    'type': 'CHAMPION_KILL',
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 9,
#      'spellName': 'sru_orderminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 15,
#      'spellName': 'sru_orderminionsiegebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 38,
#      'spellName': 'sru_orderminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 19,
#      'spellName': 'sru_orderminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': False,
#      'magicDamage': 158,
#      'name': 'Neeko',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'neekoq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 17,
#      'name': 'Neeko',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'burning',
#      'spellSlot': -1,
#      'trueDamage': 13,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 505,
#      'spellName': 'shacobasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 129,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'twoshivpoison',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 29,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'jackinthebox',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 102,
#      'spellName': 'shacobasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 8},
#   {'bounty': 300,
#    'killStreakLength': 1,
#    'killerId': 2,
#    'position': {'x': 6802, 'y': 6780},
#    'shutdownBounty': 0,
#    'timestamp': 538059,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'FiddleSticks',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 's5_summonersmiteplayerganker',
#      'spellSlot': 4,
#      'trueDamage': 40,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 445,
#      'name': 'FiddleSticks',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'fiddlesticksr',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 52,
#      'name': 'FiddleSticks',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'fiddlesticksq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 79,
#      'name': 'FiddleSticks',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'fiddlestickse',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 362,
#      'name': 'FiddleSticks',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'fiddlesticksw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'Turret',
#      'participantId': 0,
#      'physicalDamage': 1261,
#      'spellName': 'turretbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'TOWER'},
#     {'basic': False,
#      'magicDamage': 24,
#      'name': 'Shaco',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'hallucinatefull',
# ...
#      'spellName': 'respawnclassic',
#      'spellSlot': 61,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kennen',
#      'participantId': 9,
#      'physicalDamage': 28,
#      'spellName': 'respawnclassic',
#      'spellSlot': 61,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 141,
#      'name': 'Kennen',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 301,
#      'name': 'Kennen',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'kennenshurikenhurlmissile1',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kennen',
#      'participantId': 9,
#      'physicalDamage': 28,
#      'spellName': 'kennenbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionSiege',
#      'participantId': 0,
#      'physicalDamage': 91,
#      'spellName': 'sru_chaosminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionSiege',
#      'participantId': 0,
#      'physicalDamage': 68,
#      'spellName': 'sru_chaosminionsiegebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionSiege',
#      'participantId': 0,
#      'physicalDamage': 182,
#      'spellName': 'sru_chaosminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 436,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 215,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ezrealw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'burning',
#      'spellSlot': -1,
#      'trueDamage': 91,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 83,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 465,
#      'spellName': 'ezrealbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 81,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'ezreale',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ezreal',
#      'participantId': 9,
#      'physicalDamage': 548,
#      'spellName': 'ezrealq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 1},
#   {'assistingParticipantIds': [1, 4, 5],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 3,
#    'position': {'x': 3603, 'y': 6178},
#    'shutdownBounty': 600,
#    'timestamp': 1711580,
#    'type': 'CHAMPION_KILL',
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': 'yuumir',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 23,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 60,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 68,
#      'name': 'Yuumi',
#      'participantId': 5,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 56,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 0,
#      'spellName': 'kaisapassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 27,
#      'spellName': 'kaisaeattack',
#      'spellSlot': 67,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 262,
#      'name': 'Kaisa',
#      'participantId': 4,
#      'physicalDamage': 0,
#      'spellName': 'kaisaw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 213,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': 'kennenbringthelight',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 85,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 488,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': 'kennenshurikenstorm',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 113,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': '3152active',
#      'spellSlot': 8,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 173,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': 'kennenlightningrush',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 28,
#      'spellName': 'kennenbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 103,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': 'respawnclassic',
#      'spellSlot': 61,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 28,
#      'spellName': 'respawnclassic',
#      'spellSlot': 61,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 141,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 602,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 0,
#      'spellName': 'kennenshurikenhurlmissile1',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kennen',
#      'participantId': 1,
#      'physicalDamage': 28,
#      'spellName': 'kennenbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 3,
#      'physicalDamage': 45,
#      'spellName': 'neekobasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 40,
#      'name': 'Neeko',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 209,
#      'name': 'Neeko',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 9},
#   {'assistingParticipantIds': [6, 7, 9, 10],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 8,
#    'position': {'x': 4790, 'y': 6885},
#    'shutdownBounty': 0,
#    'timestamp': 1711680,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 186,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 51,
#      'name': 'Yuumi',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yuumi',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 28,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 221,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'seismicshard',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 112,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 124,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'yasuoe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 386,
#      'spellName': 'yasuocritattack3',
#      'spellSlot': 50,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 428,
#      'spellName': 'yasuoq1wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 185,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 61,
#      'spellName': 'luxbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 65,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 71,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 5},
#   {'assistingParticipantIds': [6, 8],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 10,
#    'position': {'x': 4661, 'y': 5954},
#    'shutdownBounty': 0,
#    'timestamp': 1716051,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'neekor',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 2,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'neekor',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'neekobasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 25,
#      'name': 'Neeko',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 40,
#      'name': 'Neeko',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Neeko',
#      'participantId': 9,
#      'physicalDamage': 22,
#      'spellName': '',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 209,
#      'name': 'Neeko',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 204,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'seismicshard',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 132,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 102,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 235,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'ufslash',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 206,
#      'spellName': 'obduracy',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 273,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 0,
#      'spellName': 'landslide',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Malphite',
#      'participantId': 6,
#      'physicalDamage': 61,
#      'spellName': 'malphitebasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 360,
#      'spellName': 'yasuoq1wrapper',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 381,
#      'spellName': 'yasuor',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Yasuo',
#      'participantId': 8,
#      'physicalDamage': 325,
#      'spellName': 'yasuocritattack',
#      'spellSlot': 50,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 259,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxlightbinding',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 141,
#      'name': 'Lux',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luxilluminationpassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 3}],
#  []]

# %%
df2
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6740475392          2491  13.19.534.5972
# 1    KR_6740475392          2491  13.19.534.5972
# 2    KR_6740475392          2491  13.19.534.5972
# 3    KR_6740475392          2491  13.19.534.5972
# 4    KR_6740475392          2491  13.19.534.5972
# ..             ...           ...             ...            ...           ...
# 315  KR_6783884417          1749  13.21.539.4823
# 316  KR_6783884417          1749  13.21.539.4823
# 317  KR_6783884417          1749  13.21.539.4823
# 318  KR_6783884417          1749  13.21.539.4823
# 319  KR_6783884417          1749  13.21.539.4823
#
#      summonerLevel  participantId  championName  champExperience teamPosition  \
# 0              128              1       Evelynn            20922       JUNGLE
# 1               46              2    Blitzcrank            15461      UTILITY
# 2              400              3         Talon            20584       MIDDLE
# 3              169              4       Chogath            21383          TOP
# 4              432              5         Vayne            21404       BOTTOM
# ..             ...            ...           ...              ...          ...
# 315            248              6      Malphite            14929          TOP
# 316            321              7  FiddleSticks            13490       JUNGLE
# 317             88              8         Yasuo            17074       MIDDLE
# 318            155              9        Ezreal            13504       BOTTOM
# 319            140             10           Lux            10525      UTILITY
#
#      ...  totalDamageDealtToChampions  totalDamageTaken  firstDT  laneTower  \
# 0    ...                        47409          (59270,)        0          0
# 1    ...                         9699          (33513,)        0          0
# 2    ...                        46541          (41052,)        0          1
# 3    ...                        27902          (66045,)        0          1
# 4    ...                        62688          (45343,)        0          1
# ..   ...                          ...               ...      ...        ...
# 315  ...                        13838          (18397,)        0          0
# 316  ...                        17826          (32195,)        0          0
# 317  ...                        20757          (22856,)        0          1
# 318  ...                        36263          (18078,)        0          0
# 319  ...                         8349           (8969,)        0          0
#
#      LaneTowerTime                bans  \
# 0                0  101|30|360|127|122
# 1                0  101|30|360|127|122
# 2          1788453  101|30|360|127|122
# 3           857280  101|30|360|127|122
# 4          1257995  101|30|360|127|122
# ..             ...                 ...
# 315              0   39|517|412|111|11
# 316              0   39|517|412|111|11
# 317        1742222   39|517|412|111|11
# 318              0   39|517|412|111|11
# 319              0   39|517|412|111|11
#
#                                               killerId  \
# 0    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 1    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 2    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 3    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 4    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# ..                                                 ...
# 315  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 316  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 317  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 318  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 319  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
#
#                                               victimId  \
# 0    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 1    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 2    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 3    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 4    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# ..                                                 ...
# 315  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 316  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 317  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 318  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 319  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
#
#                                               assistId   G15
# 0    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6210
# 1    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  3657
# 2    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6545
# 3    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  4451
# 4    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  5944
# ..                                                 ...   ...
# 315  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5226
# 316  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5147
# 317  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6569
# 318  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6734
# 319  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  4255
#
# [320 rows x 25 columns]

# %% [markdown]
# # blue_team이라는 데이터프레임 옆에 enemy_champ,enemy_g15의 컬럼 추가
#
# # red_team도 추가
# # blue 밑에 concat 써서 red추가

# %%
blue_team = df2[df2.teamId==100]
red_team = df2[df2.teamId==200]

# %%
team_b=blue_team[['matchId','gameVersion','teamPosition','championName','G15']]

# %%
team_r=red_team[['matchId','gameVersion','teamPosition','championName','G15']]

# %%
team_b
# Out:
#            matchId     gameVersion teamPosition championName   G15
# 0    KR_6740475392  13.19.534.5972       JUNGLE      Evelynn  6210
# 1    KR_6740475392  13.19.534.5972      UTILITY   Blitzcrank  3657
# 2    KR_6740475392  13.19.534.5972       MIDDLE        Talon  6545
# 3    KR_6740475392  13.19.534.5972          TOP      Chogath  4451
# 4    KR_6740475392  13.19.534.5972       BOTTOM        Vayne  5944
# ..             ...             ...          ...          ...   ...
# 310  KR_6783884417  13.21.539.4823          TOP       Kennen  4369
# 311  KR_6783884417  13.21.539.4823       JUNGLE        Shaco  6279
# 312  KR_6783884417  13.21.539.4823       MIDDLE        Neeko  4569
# 313  KR_6783884417  13.21.539.4823       BOTTOM        Kaisa  5854
# 314  KR_6783884417  13.21.539.4823      UTILITY        Yuumi  3742
#
# [160 rows x 5 columns]

# %%
team_r
# Out:
#            matchId     gameVersion teamPosition  championName   G15
# 5    KR_6740475392  13.19.534.5972      UTILITY         Yuumi  3763
# 6    KR_6740475392  13.19.534.5972       MIDDLE        Singed  4358
# 7    KR_6740475392  13.19.534.5972       BOTTOM      Aphelios  4490
# 8    KR_6740475392  13.19.534.5972       JUNGLE         Viego  5433
# 9    KR_6740475392  13.19.534.5972          TOP         Urgot  7212
# ..             ...             ...          ...           ...   ...
# 315  KR_6783884417  13.21.539.4823          TOP      Malphite  5226
# 316  KR_6783884417  13.21.539.4823       JUNGLE  FiddleSticks  5147
# 317  KR_6783884417  13.21.539.4823       MIDDLE         Yasuo  6569
# 318  KR_6783884417  13.21.539.4823       BOTTOM        Ezreal  6734
# 319  KR_6783884417  13.21.539.4823      UTILITY           Lux  4255
#
# [160 rows x 5 columns]

# %%
team_b=blue_team[['matchId','gameVersion','teamPosition','championName','G15']].rename(columns={'championName':'enemy_champ','G15':'enemy_G15'})

# %%
team_b_merge = pd.merge(blue_team,team_b,on=['matchId','gameVersion','teamPosition'])

# %%
team_b_merge
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6740475392          2491  13.19.534.5972
# 1    KR_6740475392          2491  13.19.534.5972
# 2    KR_6740475392          2491  13.19.534.5972
# 3    KR_6740475392          2491  13.19.534.5972
# 4    KR_6740475392          2491  13.19.534.5972
# ..             ...           ...             ...            ...           ...
# 155  KR_6783884417          1749  13.21.539.4823
# 156  KR_6783884417          1749  13.21.539.4823
# 157  KR_6783884417          1749  13.21.539.4823
# 158  KR_6783884417          1749  13.21.539.4823
# 159  KR_6783884417          1749  13.21.539.4823
#
#      summonerLevel  participantId championName  champExperience teamPosition  \
# 0              128              1      Evelynn            20922       JUNGLE
# 1               46              2   Blitzcrank            15461      UTILITY
# 2              400              3        Talon            20584       MIDDLE
# 3              169              4      Chogath            21383          TOP
# 4              432              5        Vayne            21404       BOTTOM
# ..             ...            ...          ...              ...          ...
# 155            231              1       Kennen            12413          TOP
# 156            167              2        Shaco            11922       JUNGLE
# 157            240              3        Neeko            14950       MIDDLE
# 158             92              4        Kaisa            11105       BOTTOM
# 159            244              5        Yuumi            10507      UTILITY
#
#      ...  firstDT  laneTower  LaneTowerTime                bans  \
# 0    ...        0          0              0  101|30|360|127|122
# 1    ...        0          0              0  101|30|360|127|122
# 2    ...        0          1        1788453  101|30|360|127|122
# 3    ...        0          1         857280  101|30|360|127|122
# 4    ...        0          1        1257995  101|30|360|127|122
# ..   ...      ...        ...            ...                 ...
# 155  ...        0          1        1046079   39|517|412|111|11
# 156  ...        0          0              0   39|517|412|111|11
# 157  ...        1          1         848793   39|517|412|111|11
# 158  ...        0          1        1018975   39|517|412|111|11
# 159  ...        0          0              0   39|517|412|111|11
#
#                                               killerId  \
# 0    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 1    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 2    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 3    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 4    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# ..                                                 ...
# 155  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 156  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 157  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 158  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 159  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
#
#                                               victimId  \
# 0    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 1    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 2    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 3    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 4    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# ..                                                 ...
# 155  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 156  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 157  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 158  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 159  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
#
#                                               assistId   G15  enemy_champ  \
# 0    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6210      Evelynn
# 1    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  3657   Blitzcrank
# 2    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6545        Talon
# 3    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  4451      Chogath
# 4    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  5944        Vayne
# ..                                                 ...   ...          ...
# 155  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  4369       Kennen
# 156  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6279        Shaco
# 157  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  4569        Neeko
# 158  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5854        Kaisa
# 159  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  3742        Yuumi
#
#      enemy_G15
# 0         6210
# 1         3657
# 2         6545
# 3         4451
# 4         5944
# ..         ...
# 155       4369
# 156       6279
# 157       4569
# 158       5854
# 159       3742
#
# [160 rows x 27 columns]

# %%
team_r=red_team[['matchId','gameVersion','teamPosition','championName','G15']].rename(columns={'championName':'enemy_champ','G15':'enemy_G15'})

# %%
team_r_merge = pd.merge(red_team,team_r,on=['matchId','gameVersion','teamPosition'])

# %%
team_r_merge
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6740475392          2491  13.19.534.5972
# 1    KR_6740475392          2491  13.19.534.5972
# 2    KR_6740475392          2491  13.19.534.5972
# 3    KR_6740475392          2491  13.19.534.5972
# 4    KR_6740475392          2491  13.19.534.5972
# ..             ...           ...             ...            ...           ...
# 155  KR_6783884417          1749  13.21.539.4823
# 156  KR_6783884417          1749  13.21.539.4823
# 157  KR_6783884417          1749  13.21.539.4823
# 158  KR_6783884417          1749  13.21.539.4823
# 159  KR_6783884417          1749  13.21.539.4823
#
#      summonerLevel  participantId  championName  champExperience teamPosition  \
# 0              269              6         Yuumi            20701      UTILITY
# 1              359              7        Singed            24064       MIDDLE
# 2              200              8      Aphelios            18915       BOTTOM
# 3              119              9         Viego            21815       JUNGLE
# 4              219             10         Urgot            26292          TOP
# ..             ...            ...           ...              ...          ...
# 155            248              6      Malphite            14929          TOP
# 156            321              7  FiddleSticks            13490       JUNGLE
# 157             88              8         Yasuo            17074       MIDDLE
# 158            155              9        Ezreal            13504       BOTTOM
# 159            140             10           Lux            10525      UTILITY
#
#      ...  firstDT  laneTower  LaneTowerTime                bans  \
# 0    ...        0          0              0  101|30|360|127|122
# 1    ...        1          1         789812  101|30|360|127|122
# 2    ...        0          1        1003990  101|30|360|127|122
# 3    ...        0          0              0  101|30|360|127|122
# 4    ...        0          1        1167754  101|30|360|127|122
# ..   ...      ...        ...            ...                 ...
# 155  ...        0          0              0   39|517|412|111|11
# 156  ...        0          0              0   39|517|412|111|11
# 157  ...        0          1        1742222   39|517|412|111|11
# 158  ...        0          0              0   39|517|412|111|11
# 159  ...        0          0              0   39|517|412|111|11
#
#                                               killerId  \
# 0    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 1    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 2    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 3    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 4    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# ..                                                 ...
# 155  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 156  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 157  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 158  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 159  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
#
#                                               victimId  \
# 0    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 1    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 2    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 3    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 4    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# ..                                                 ...
# 155  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 156  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 157  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 158  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 159  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
#
#                                               assistId   G15   enemy_champ  \
# 0    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  3763         Yuumi
# 1    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  4358        Singed
# 2    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  4490      Aphelios
# 3    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  5433         Viego
# 4    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  7212         Urgot
# ..                                                 ...   ...           ...
# 155  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5226      Malphite
# 156  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5147  FiddleSticks
# 157  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6569         Yasuo
# 158  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6734        Ezreal
# 159  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  4255           Lux
#
#      enemy_G15
# 0         3763
# 1         4358
# 2         4490
# 3         5433
# 4         7212
# ..         ...
# 155       5226
# 156       5147
# 157       6569
# 158       6734
# 159       4255
#
# [160 rows x 27 columns]

# %%
team_df=pd.concat([team_b_merge,team_r_merge])

# %%
team_df
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6740475392          2491  13.19.534.5972
# 1    KR_6740475392          2491  13.19.534.5972
# 2    KR_6740475392          2491  13.19.534.5972
# 3    KR_6740475392          2491  13.19.534.5972
# 4    KR_6740475392          2491  13.19.534.5972
# ..             ...           ...             ...            ...           ...
# 155  KR_6783884417          1749  13.21.539.4823
# 156  KR_6783884417          1749  13.21.539.4823
# 157  KR_6783884417          1749  13.21.539.4823
# 158  KR_6783884417          1749  13.21.539.4823
# 159  KR_6783884417          1749  13.21.539.4823
#
#      summonerLevel  participantId  championName  champExperience teamPosition  \
# 0              128              1       Evelynn            20922       JUNGLE
# 1               46              2    Blitzcrank            15461      UTILITY
# 2              400              3         Talon            20584       MIDDLE
# 3              169              4       Chogath            21383          TOP
# 4              432              5         Vayne            21404       BOTTOM
# ..             ...            ...           ...              ...          ...
# 155            248              6      Malphite            14929          TOP
# 156            321              7  FiddleSticks            13490       JUNGLE
# 157             88              8         Yasuo            17074       MIDDLE
# 158            155              9        Ezreal            13504       BOTTOM
# 159            140             10           Lux            10525      UTILITY
#
#      ...  firstDT  laneTower  LaneTowerTime                bans  \
# 0    ...        0          0              0  101|30|360|127|122
# 1    ...        0          0              0  101|30|360|127|122
# 2    ...        0          1        1788453  101|30|360|127|122
# 3    ...        0          1         857280  101|30|360|127|122
# 4    ...        0          1        1257995  101|30|360|127|122
# ..   ...      ...        ...            ...                 ...
# 155  ...        0          0              0   39|517|412|111|11
# 156  ...        0          0              0   39|517|412|111|11
# 157  ...        0          1        1742222   39|517|412|111|11
# 158  ...        0          0              0   39|517|412|111|11
# 159  ...        0          0              0   39|517|412|111|11
#
#                                               killerId  \
# 0    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 1    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 2    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 3    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# 4    3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# ..                                                 ...
# 155  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 156  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 157  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 158  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
# 159  9|8|5|2|7|9|4|6|8|6|9|9|8|9|2|2|4|4|1|8|6|2|2|...
#
#                                               victimId  \
# 0    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 1    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 2    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 3    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# 4    7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# ..                                                 ...
# 155  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 156  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 157  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 158  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
# 159  4|3|9|8|2|5|9|1|3|2|4|5|3|4|8|7|9|10|6|3|1|6|1...
#
#                                               assistId   G15   enemy_champ  \
# 0    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6210       Evelynn
# 1    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  3657    Blitzcrank
# 2    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  6545         Talon
# 3    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  4451       Chogath
# 4    ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...  5944         Vayne
# ..                                                 ...   ...           ...
# 155  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5226      Malphite
# 156  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  5147  FiddleSticks
# 157  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6569         Yasuo
# 158  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  6734        Ezreal
# 159  10||4||8|10|2|||8|10|10|7|10|||5|5||7|||4,5|7|...  4255           Lux
#
#      enemy_G15
# 0         6210
# 1         3657
# 2         6545
# 3         4451
# 4         5944
# ..         ...
# 155       5226
# 156       5147
# 157       6569
# 158       6734
# 159       4255
#
# [320 rows x 27 columns]

# %% [markdown]
# # lane_win

# %%
team_df['lane_win'] = team_df.apply(lambda x:1 if x.G15 > x.enemy_G15 else 0,axis=1)

# %%
team_df['first_blood']=team_df.apply(lambda x:1 if str(x.participantId)==x.killerId.split('|')[0] else 0,axis=1)

# %%
team_df.iloc[0].killerId.split('|')[0]
# Out:
# '3'

# %%
# Out:
# matchId                                                            KR_6740475392
# gameDuration                                                                2491
# gameVersion                                                       13.19.534.5972
# riotIdGameName
# riotIdTagline
# summonerLevel                                                                128
# participantId                                                                  1
# championName                                                             Evelynn
# champExperience                                                            20922
# teamPosition                                                              JUNGLE
# teamId                                                                       100
# win                                                                        False
# kills                                                                         12
# deaths                                                                        11
# assists                                                                       14
# totalDamageDealtToChampions                                                47409
# totalDamageTaken                                                        (59270,)
# firstDT                                                                        0
# laneTower                                                                      0
# LaneTowerTime                                                                  0
# bans                                                          101|30|360|127|122
# killerId                       3|4|5|4|10|8|10|3|1|10|4|10|5|5|6|3|1|9|5|7|10...
# victimId                       7|10|8|9|1|1|4|7|10|4|9|4|8|6|5|7|10|1|8|5|4|4...
# assistId                       ||2|1|9|6,7,9||||9|1||2|2||||10|2|6||9|6|2,5|3...
# G15                                                                         6210
# enemy_champ                                                              Evelynn
# enemy_G15                                                                   6210
# lane_win                                                                       0
# first_blood                                                                    0
# Name: 0, dtype: object
